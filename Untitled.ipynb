# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('antall_smittede_norge.csv',delimiter=';')
df['dag_etter_start']=[i for i in range(len(df['dato']))]
df['dato']=pd.to_datetime(df['dato'], dayfirst=True)
#fig, ax = plt.subplots()

ax = df.plot(kind='line',x='dato',y='total')

df['nye']=np.NaN
for i in range(1,len(df['dato'])):
    df['nye'][i]=df['total'][i]-df['total'][i-1]
fig, ax = plt.subplots()
ax = df.plot(kind='line',x='dag_etter_start',y='nye')
ax = df.plot(kind='line',x='dato',y='nye')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# \begin{align}
# \dot{x} & = \sigma(y-x) \\
# \dot{y} & = \rho x - y - xz \\
# \dot{z} & = -\beta z + xy
# \end{align}

# %% [markdown]
# $
#     \int_0^\infty \frac{x^3}{e^x-1}\,dx = \frac{\pi^4}{15}
# $

# %% [markdown]
# Vi kjører da en regresjon på formen $y=ax+b^2$

# %% [markdown]
# ![image.png](attachment:image.png)
